# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
df = pd.read_csv("covid_north_america.csv")

# %%
df
# Out:
#              Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0                 Anguilla          944           1.0              832
# 1      Antigua and Barbuda         4058         102.0             3726
# 2                    Aruba        15925         171.0            15577
# 3                  Bahamas        22351         643.0            21079
# 4                 Barbados        17763         153.0            11506
# 5                   Belize        26798         491.0            23706
# 6                  Bermuda         5647         101.0             5462
# 7   British Virgin Islands         2725          37.0             2649
# 8                   Canada      1714414       28968.0          1659368
# 9    Caribbean Netherlands         2435          19.0             2340
# 10          Cayman Islands         1650           2.0             1002
# 11              Costa Rica       559698        7029.0           500425
# ...

# %%
df.head()
# Out:
#          Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0             Anguilla          944           1.0              832
# 1  Antigua and Barbuda         4058         102.0             3726
# 2                Aruba        15925         171.0            15577
# 3              Bahamas        22351         643.0            21079
# 4             Barbados        17763         153.0            11506
#
#    Active Cases  Total Cases/1 mil population  Deaths/1 mil population  \
# 0           111                         62183                     66.0
# 1           230                         40987                   1030.0
# 2           177                        148320                   1593.0
# 3           629                         56124                   1615.0
# 4          6104                         61711                    532.0
#
#    Total Tests  Tests/1 mil population  Population
# 0      47917.0               3156380.0       15181
# ...

# %%
df.describe()
# Out:
#         Total Cases   Total Deaths  Total Recovered  Active Cases  \
# count  3.800000e+01      37.000000     3.800000e+01  3.800000e+01
# mean   1.480208e+06   31031.297297     1.181240e+06  2.687535e+05
# std    7.585157e+06  132928.839813     5.949429e+06  1.513258e+06
# min    4.100000e+01       1.000000     3.400000e+01  6.000000e+00
# 25%    3.918500e+03      56.000000     2.545500e+03  1.260000e+02
# 50%    1.675300e+04     207.000000     8.512500e+03  2.061500e+03
# 75%    1.073200e+05    3629.000000     8.571100e+04  1.060175e+04
# max    4.682394e+07  766299.000000     3.671531e+07  9.342326e+06
#
#        Total Cases/1 mil population  Deaths/1 mil population   Total Tests  \
# count                     38.000000                37.000000  3.700000e+01
# mean                   66769.921053              1007.891892  2.123956e+07
# std                    41768.641901               628.590477  1.147321e+08
# ...

# %%
df["Total Cases"]
# Out:
# 0          944
# 1         4058
# 2        15925
# 3        22351
# 4        17763
# 5        26798
# 6         5647
# 7         2725
# 8      1714414
# 9         2435
# 10        1650
# 11      559698
# 12      952001
# 13       17084
# 14        4823
# 15      381667
# 16      113422
# 17         799
# 18        5840
# 19       54537
# 20      601572
# 21       23960
# 22      375381
# 23       89014
# 24       42634
# 25     3807211
# 26          41
# 27       16422
# 28      472664
# 29        2669
# 30       12559
# 31        3872
# 32        4494
# 33        1589
# 34        4995
# 35       57329
# 36        2980
# 37    46823938
# Name: Total Cases, dtype: int64

# %%
names = data['Nationals Pitchers']
data_file = open('first-project.csv','w')
csv_writer = csv.writer(data_file)
csv_writer.writerow(names[0].keys())
for name in names:
    csv_writer.writerow(name.values())
data_file.close()

# %%
df = pd.read_csv('first-project.csv')
df
# Out:
#     Joan Adon
# 0          60
# 1          40
# 2          49
# 3          46
# 4          23
# 5          40
# 6          21
# 7          65
# 8          51
# 9          50
# 10         33

# %%
import json
import csv
import pandas as pd

# %%
with open('first-project.json') as json_file:
    data = json.load(json_file)
print(data)
