# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('swift-spotify.csv')
df
# Out:
#      Unnamed: 0                                               name  \
# 0             0                                         Tim McGraw
# 1             1                                    Picture To Burn
# 2             2        Teardrops On My Guitar - Radio Single Remix
# 3             3                              A Place in this World
# 4             4                                        Cold As You
# ..          ...                                                ...
# 166         166  Mr. Perfectly Fine (Taylor’s Version) (From Th...
# 167         167  We Were Happy (Taylor’s Version) (From The Vault)
# 168         168  That’s When (feat. Keith Urban) (Taylor’s Vers...
# 169         169      Don’t You (Taylor’s Version) (From The Vault)
# 170         170   Bye Bye Baby (Taylor’s Version) (From The Vault)
#
#                            album        artist release_date  length  \
# 0                   Taylor Swift  Taylor Swift   2006-10-24  232106
# ...

# %%
df2 = df[['name','album','artist','release_date','length','popularity', 'danceability']]
df2
# Out:
#                                                   name  \
# 0                                           Tim McGraw
# 1                                      Picture To Burn
# 2          Teardrops On My Guitar - Radio Single Remix
# 3                                A Place in this World
# 4                                          Cold As You
# ..                                                 ...
# 166  Mr. Perfectly Fine (Taylor’s Version) (From Th...
# 167  We Were Happy (Taylor’s Version) (From The Vault)
# 168  That’s When (feat. Keith Urban) (Taylor’s Vers...
# 169      Don’t You (Taylor’s Version) (From The Vault)
# 170   Bye Bye Baby (Taylor’s Version) (From The Vault)
#
#                            album        artist release_date  length  \
# 0                   Taylor Swift  Taylor Swift   2006-10-24  232106
# 1                   Taylor Swift  Taylor Swift   2006-10-24  173066
# 2                   Taylor Swift  Taylor Swift   2006-10-24  203040
# ...

# %%
df3 = df2.loc[df2['album'].str.contains('Fearless')]
df3
# Out:
#                                                   name  \
# 145                        Fearless (Taylor’s Version)
# 146                         Fifteen (Taylor’s Version)
# 147                      Love Story (Taylor’s Version)
# 148                     Hey Stephen (Taylor’s Version)
# 149                     White Horse (Taylor’s Version)
# 150              You Belong With Me (Taylor’s Version)
# 151  Breathe (feat. Colbie Caillat) (Taylor’s Version)
# 152                     Tell Me Why (Taylor’s Version)
# 153                You’re Not Sorry (Taylor’s Version)
# 154             The Way I Loved You (Taylor’s Version)
# 155                Forever & Always (Taylor’s Version)
# 156                    The Best Day (Taylor’s Version)
# 157                          Change (Taylor’s Version)
# 158                  Jump Then Fall (Taylor’s Version)
# 159                     Untouchable (Taylor’s Version)
# 160  Forever & Always (Piano Version) (Taylor’s Ver...
# ...

# %%
df4 = df2.loc[df2['album'].str.contains('Red') & df2['name'].str.contains('All Too Well')]
df4
# Out:
#             name                 album        artist release_date  length  \
# 41  All Too Well  Red (Deluxe Edition)  Taylor Swift   2012-10-22  329160
#
#     popularity  danceability
# 41          72         0.602

# %%
df.dropna()
# Out:
#      Unnamed: 0                                               name  \
# 0             0                                         Tim McGraw
# 1             1                                    Picture To Burn
# 2             2        Teardrops On My Guitar - Radio Single Remix
# 3             3                              A Place in this World
# 4             4                                        Cold As You
# ..          ...                                                ...
# 166         166  Mr. Perfectly Fine (Taylor’s Version) (From Th...
# 167         167  We Were Happy (Taylor’s Version) (From The Vault)
# 168         168  That’s When (feat. Keith Urban) (Taylor’s Vers...
# 169         169      Don’t You (Taylor’s Version) (From The Vault)
# 170         170   Bye Bye Baby (Taylor’s Version) (From The Vault)
#
#                            album        artist release_date  length  \
# 0                   Taylor Swift  Taylor Swift   2006-10-24  232106
# ...

# %%
df5 = df.loc[df['danceability']<0.5]
df5
# Out:
#      Unnamed: 0                                           name  \
# 4             4                                    Cold As You
# 6             6                     Tied Together with a Smile
# 8             8                              Should've Said No
# 9             9                      Mary's Song (Oh My My My)
# 13           13                         A Perfectly Good Heart
# 14           14           Teardrops on My Guitar - Pop Version
# 26           26                                        Haunted
# 27           27                                      Last Kiss
# 28           28                                      Long Live
# 54           54                            Come Back...Be Here
# 69           69                                      This Love
# 72           72                                     Wonderland
# 73           73                                You Are In Love
# 95           95                                          Lover
# ...

# %%
df6 = df5.loc[:, ['name', 'acousticness','danceability']]
df6
# Out:
#                                               name  acousticness  danceability
# 4                                      Cold As You      0.217000         0.418
# 6                       Tied Together with a Smile      0.525000         0.479
# 8                                Should've Said No      0.010300         0.476
# 9                        Mary's Song (Oh My My My)      0.017700         0.403
# 13                          A Perfectly Good Heart      0.003490         0.483
# 14            Teardrops on My Guitar - Pop Version      0.040200         0.459
# 26                                         Haunted      0.076900         0.434
# 27                                       Last Kiss      0.581000         0.359
# 28                                       Long Live      0.042600         0.412
# 54                             Come Back...Be Here      0.004710         0.483
# 69                                       This Love      0.678000         0.481
# ...

# %%
df6.corr()
# Out:
#               acousticness  danceability
# acousticness      1.000000     -0.368507
# danceability     -0.368507      1.000000
